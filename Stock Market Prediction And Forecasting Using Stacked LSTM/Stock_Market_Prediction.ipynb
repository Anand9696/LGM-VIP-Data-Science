# %% [markdown]
# # LetsGrowMore #December2021
#
# # Author :- Anand Bhausaheb Kharabe
#
# # Task :- 1.2) Stock Market Prediction And Forecasting Using Stacked LSTM
#
# Level :- Beginner
#
# Language :- Python
#
# Software :- Jupyter Notebook
#
# Dataset Link :- https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv

# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from sklearn.preprocessing import MinMaxScaler

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Reading the Dataset

# %%
df = pd.read_csv("NSE-TATAGLOBAL.csv")

# %%
df.head()
# Out:
#          Date    Open    High     Low    Last   Close  Total Trade Quantity  \
# 0  2018-09-28  234.05  235.95  230.20  233.50  233.75               3069914
# 1  2018-09-27  234.55  236.80  231.10  233.80  233.25               5082859
# 2  2018-09-26  240.00  240.00  232.50  235.00  234.25               2240909
# 3  2018-09-25  233.30  236.75  232.00  236.25  236.10               2349368
# 4  2018-09-24  233.55  239.20  230.75  234.00  233.30               3423509
#
#    Turnover (Lacs)
# 0          7162.35
# 1         11859.95
# 2          5248.60
# 3          5503.90
# 4          7999.55

# %% [markdown]
# # Data Sorting

# %%
df['Date']=pd.to_datetime(df['Date'])
print(type(df.Date[0]))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
data=df.sort_values(by='Date')
data.head()
# Out:
#            Date   Open    High     Low    Last   Close  Total Trade Quantity  \
# 2034 2010-07-21  122.1  123.00  121.05  121.10  121.55                658666
# 2033 2010-07-22  120.3  122.00  120.25  120.75  120.90                293312
# 2032 2010-07-23  121.8  121.95  120.25  120.35  120.65                281312
# 2031 2010-07-26  120.1  121.00  117.10  117.10  117.60                658440
# 2030 2010-07-27  117.6  119.50  112.00  118.80  118.65                586100
#
#       Turnover (Lacs)
# 2034           803.56
# 2033           355.17
# 2032           340.31
# 2031           780.01
# 2030           694.98

# %%
data.reset_index(inplace=True)

# %%
data.head()
# Out:
#    index       Date   Open    High     Low    Last   Close  \
# 0   2034 2010-07-21  122.1  123.00  121.05  121.10  121.55
# 1   2033 2010-07-22  120.3  122.00  120.25  120.75  120.90
# 2   2032 2010-07-23  121.8  121.95  120.25  120.35  120.65
# 3   2031 2010-07-26  120.1  121.00  117.10  117.10  117.60
# 4   2030 2010-07-27  117.6  119.50  112.00  118.80  118.65
#
#    Total Trade Quantity  Turnover (Lacs)
# 0                658666           803.56
# 1                293312           355.17
# 2                281312           340.31
# 3                658440           780.01
# 4                586100           694.98

# %% [markdown]
# # Visualization

# %%
plt.plot(data['Close'])

# %%
dff=data['Close']
dff
# Out:
# 0       121.55
# 1       120.90
# 2       120.65
# 3       117.60
# 4       118.65
#          ...
# 2030    233.30
# 2031    236.10
# 2032    234.25
# 2033    233.25
# 2034    233.75
# Name: Close, Length: 2035, dtype: float64

# %% [markdown]
# # Min Max Scaler

# %%
scaler=MinMaxScaler(feature_range=(0,1))
dff=scaler.fit_transform(np.array(dff).reshape(-1,1))
dff
# Out:
# array([[0.16584967],
#        [0.16319444],
#        [0.1621732 ],
#        ...,
#        [0.62622549],
#        [0.62214052],
#        [0.62418301]])

# %% [markdown]
# # Spliting the Dataset

# %%
training_size=int(len(dff)*0.70)
test_size=len(dff)-training_size
train_data,test_data=dff[0:training_size,:],dff[training_size:len(dff),:1]

# %% [markdown]
# # Convert an array of values into a dataset matrix

# %%
def create_dataset(dataset, time_step=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-time_step-1):
        a = dataset[i:(i+time_step), 0]
        dataX.append(a)
        dataY.append(dataset[i + time_step, 0])
    return np.array(dataX), np.array(dataY)

# %% [markdown]
# # Spliting Data into Train and Test

# %%
time_step = 100
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
print(X_train.shape), print(y_train.shape)
# Out:
# (1323, 100)
# (1323,)
# (None, None)

# %%
print(X_test.shape), print(ytest.shape)
# Out:
# (510, 100)
# (510,)
# (None, None)

# %%
X_train =X_train.reshape(X_train.shape[0],X_train.shape[1] , 1)
X_test = X_test.reshape(X_test.shape[0],X_test.shape[1] , 1)

# %% [markdown]
# # Creating the LSTM Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(100,1)))
model.add(LSTM(50,return_sequences=True))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  (None, 100, 50)           10400
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 100, 50)           20200
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 50)                20200
# _________________________________________________________________
# dense (Dense)                (None, 1)                 51
# =================================================================
# Total params: 50,851
# Trainable params: 50,851
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,validation_split=0.1,epochs=78,batch_size=64,verbose=1)
# Out:
# Epoch 1/78
# 19/19 [==============================] - 2s 125ms/step - loss: 1.3468e-04 - val_loss: 1.1489e-04
# Epoch 2/78
# 19/19 [==============================] - 2s 113ms/step - loss: 1.3177e-04 - val_loss: 1.2903e-04
# Epoch 3/78
# 19/19 [==============================] - 2s 114ms/step - loss: 1.4196e-04 - val_loss: 1.3098e-04
# Epoch 4/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.3606e-04 - val_loss: 1.2611e-04
# Epoch 5/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.4387e-04 - val_loss: 1.3046e-04
# Epoch 6/78
# 19/19 [==============================] - 2s 114ms/step - loss: 1.2287e-04 - val_loss: 1.1128e-04
# Epoch 7/78
# 19/19 [==============================] - 2s 124ms/step - loss: 1.2896e-04 - val_loss: 1.2211e-04
# Epoch 8/78
# 19/19 [==============================] - 2s 119ms/step - loss: 1.4926e-04 - val_loss: 1.1875e-04
# Epoch 9/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2930e-04 - val_loss: 1.2124e-04
# Epoch 10/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2232e-04 - val_loss: 1.1003e-04
# Epoch 11/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2116e-04 - val_loss: 1.2856e-04
# Epoch 12/78
# 19/19 [==============================] - 2s 117ms/step - loss: 1.2330e-04 - val_loss: 1.1296e-04
# Epoch 13/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2871e-04 - val_loss: 1.4156e-04
# Epoch 14/78
# 19/19 [==============================] - 2s 118ms/step - loss: 1.3411e-04 - val_loss: 1.1018e-04
# Epoch 15/78
# 19/19 [==============================] - 2s 117ms/step - loss: 1.2359e-04 - val_loss: 1.1278e-04
# Epoch 16/78
# 19/19 [==============================] - 2s 119ms/step - loss: 1.2496e-04 - val_loss: 1.1146e-04
# Epoch 17/78
# 19/19 [==============================] - 2s 127ms/step - loss: 1.2348e-04 - val_loss: 1.1263e-04
# Epoch 18/78
# 19/19 [==============================] - 2s 122ms/step - loss: 1.2443e-04 - val_loss: 1.1093e-04
# Epoch 19/78
# 19/19 [==============================] - 2s 124ms/step - loss: 1.2785e-04 - val_loss: 1.2190e-04
# Epoch 20/78
# 19/19 [==============================] - 2s 119ms/step - loss: 1.2463e-04 - val_loss: 1.1169e-04
# Epoch 21/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2186e-04 - val_loss: 1.1018e-04
# Epoch 22/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2281e-04 - val_loss: 1.1324e-04
# Epoch 23/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.3200e-04 - val_loss: 1.2892e-04
# Epoch 24/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.3075e-04 - val_loss: 1.1382e-04
# Epoch 25/78
# 19/19 [==============================] - 2s 114ms/step - loss: 1.2422e-04 - val_loss: 1.1207e-04
# Epoch 26/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.3192e-04 - val_loss: 1.1064e-04
# Epoch 27/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2240e-04 - val_loss: 1.1357e-04
# Epoch 28/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.3089e-04 - val_loss: 1.1190e-04
# Epoch 29/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2178e-04 - val_loss: 1.1003e-04
# Epoch 30/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2232e-04 - val_loss: 1.3940e-04
# Epoch 31/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.3075e-04 - val_loss: 1.1742e-04
# Epoch 32/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2492e-04 - val_loss: 1.1026e-04
# Epoch 33/78
# 19/19 [==============================] - 2s 114ms/step - loss: 1.2644e-04 - val_loss: 1.1127e-04
# Epoch 34/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2345e-04 - val_loss: 1.2368e-04
# Epoch 35/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2522e-04 - val_loss: 1.1063e-04
# Epoch 36/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2226e-04 - val_loss: 1.1195e-04
# Epoch 37/78
# 19/19 [==============================] - 2s 127ms/step - loss: 1.2911e-04 - val_loss: 1.5328e-04
# Epoch 38/78
# 19/19 [==============================] - 3s 144ms/step - loss: 1.2832e-04 - val_loss: 1.1383e-04
# Epoch 39/78
# 19/19 [==============================] - 2s 118ms/step - loss: 1.2378e-04 - val_loss: 1.1071e-04
# Epoch 40/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2433e-04 - val_loss: 1.1600e-04
# Epoch 41/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2099e-04 - val_loss: 1.1903e-04
# Epoch 42/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.3219e-04 - val_loss: 1.2883e-04
# Epoch 43/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2555e-04 - val_loss: 1.1535e-04
# Epoch 44/78
# 19/19 [==============================] - 2s 124ms/step - loss: 1.2267e-04 - val_loss: 1.2582e-04
# Epoch 45/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2669e-04 - val_loss: 1.1593e-04
# Epoch 46/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.3125e-04 - val_loss: 1.0977e-04
# Epoch 47/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2405e-04 - val_loss: 1.1787e-04
# Epoch 48/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2659e-04 - val_loss: 1.1407e-04
# Epoch 49/78
# 19/19 [==============================] - 2s 117ms/step - loss: 1.2203e-04 - val_loss: 1.0976e-04
# Epoch 50/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2228e-04 - val_loss: 1.1844e-04
# Epoch 51/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2138e-04 - val_loss: 1.1125e-04
# Epoch 52/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.3097e-04 - val_loss: 1.2921e-04
# Epoch 53/78
# 19/19 [==============================] - 2s 114ms/step - loss: 1.3454e-04 - val_loss: 1.1701e-04
# Epoch 54/78
# 19/19 [==============================] - 2s 121ms/step - loss: 1.3196e-04 - val_loss: 1.1025e-04
# Epoch 55/78
# 19/19 [==============================] - 3s 143ms/step - loss: 1.2215e-04 - val_loss: 1.1150e-04
# Epoch 56/78
# 19/19 [==============================] - 3s 133ms/step - loss: 1.2160e-04 - val_loss: 1.1700e-04
# Epoch 57/78
# 19/19 [==============================] - 2s 124ms/step - loss: 1.2821e-04 - val_loss: 1.1090e-04
# Epoch 58/78
# 19/19 [==============================] - 3s 132ms/step - loss: 1.3714e-04 - val_loss: 1.3573e-04
# Epoch 59/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2669e-04 - val_loss: 1.1042e-04
# Epoch 60/78
# 19/19 [==============================] - 2s 119ms/step - loss: 1.2644e-04 - val_loss: 1.1555e-04
# Epoch 61/78
# 19/19 [==============================] - 2s 120ms/step - loss: 1.2464e-04 - val_loss: 1.3460e-04
# Epoch 62/78
# 19/19 [==============================] - 2s 120ms/step - loss: 1.2959e-04 - val_loss: 1.3330e-04
# Epoch 63/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2953e-04 - val_loss: 1.1828e-04
# Epoch 64/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.3178e-04 - val_loss: 1.1505e-04
# Epoch 65/78
# 19/19 [==============================] - 2s 117ms/step - loss: 1.2260e-04 - val_loss: 1.1234e-04
# Epoch 66/78
# 19/19 [==============================] - 2s 118ms/step - loss: 1.2594e-04 - val_loss: 1.1049e-04
# Epoch 67/78
# 19/19 [==============================] - 2s 117ms/step - loss: 1.2607e-04 - val_loss: 1.1574e-04
# Epoch 68/78
# 19/19 [==============================] - 2s 120ms/step - loss: 1.3038e-04 - val_loss: 1.5529e-04
# Epoch 69/78
# 19/19 [==============================] - 2s 118ms/step - loss: 1.2446e-04 - val_loss: 1.1299e-04
# Epoch 70/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2339e-04 - val_loss: 1.1522e-04
# Epoch 71/78
# 19/19 [==============================] - 2s 120ms/step - loss: 1.3066e-04 - val_loss: 1.2361e-04
# Epoch 72/78
# 19/19 [==============================] - 2s 120ms/step - loss: 1.2153e-04 - val_loss: 1.1765e-04
# Epoch 73/78
# 19/19 [==============================] - 2s 117ms/step - loss: 1.2572e-04 - val_loss: 1.1596e-04
# Epoch 74/78
# 19/19 [==============================] - 2s 119ms/step - loss: 1.2819e-04 - val_loss: 1.3247e-04
# Epoch 75/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2392e-04 - val_loss: 1.1112e-04
# Epoch 76/78
# 19/19 [==============================] - 2s 118ms/step - loss: 1.2361e-04 - val_loss: 1.1516e-04
# Epoch 77/78
# 19/19 [==============================] - 2s 116ms/step - loss: 1.2592e-04 - val_loss: 1.1877e-04
# Epoch 78/78
# 19/19 [==============================] - 2s 115ms/step - loss: 1.2806e-04 - val_loss: 1.0998e-04

# %% [markdown]
# # Prediction and Checking Performance

# %%
test_predict=model.predict(X_test)

# %%
test_predicted=scaler.inverse_transform(test_predict)
test_predicted
# Out:
# array([[142.05377 ],
#        [142.04634 ],
#        [139.56337 ],
#        [135.22015 ],
#        [137.28072 ],
#        [137.08586 ],
#        [139.86757 ],
#        [140.02954 ],
#        [138.07248 ],
#        [138.01015 ],
#        [138.8704  ],
#        [142.3432  ],
#        [140.68146 ],
#        [144.36542 ],
#        [146.61278 ],
#        [136.792   ],
#        [139.19862 ],
#        [142.18318 ],
#        [141.75641 ],
#        [153.0984  ],
#        [150.79547 ],
#        [150.69664 ],
#        [151.04167 ],
#        [147.17978 ],
#        [152.63982 ],
#        [149.72943 ],
#        [151.30345 ],
#        [154.08592 ],
#        [151.74765 ],
#        [151.85197 ],
#        [153.481   ],
#        [149.41133 ],
#        [144.85866 ],
#        [137.5332  ],
#        [139.72609 ],
#        [139.57259 ],
#        [138.84598 ],
#        [135.34857 ],
#        [131.77776 ],
#        [127.44681 ],
#        [128.32254 ],
#        [128.04933 ],
#        [122.90949 ],
#        [125.64685 ],
#        [119.7913  ],
#        [117.67087 ],
#        [121.42652 ],
#        [119.46703 ],
#        [120.54967 ],
#        [116.49021 ],
#        [117.52091 ],
#        [117.96582 ],
#        [115.66    ],
#        [118.52263 ],
#        [121.107605],
#        [122.22699 ],
#        [123.9724  ],
#        [122.085754],
#        [121.520905],
#        [123.471985],
#        [123.39932 ],
#        [122.34098 ],
#        [123.75829 ],
#        [123.93704 ],
#        [123.43794 ],
#        [123.4117  ],
#        [122.86345 ],
#        [124.48227 ],
#        [124.47766 ],
#        [124.467354],
#        [121.54236 ],
#        [121.692635],
#        [119.696014],
#        [119.097565],
#        [117.394226],
#        [120.62247 ],
#        [120.08967 ],
#        [121.414665],
#        [122.30831 ],
#        [123.77791 ],
#        [124.65364 ],
#        [124.61168 ],
#        [125.24581 ],
#        [124.70919 ],
#        [124.752556],
#        [124.47436 ],
#        [127.46403 ],
#        [125.34318 ],
#        [128.27596 ],
#        [127.76399 ],
#        [127.65596 ],
#        [128.64868 ],
#        [130.5037  ],
#        [126.59808 ],
#        [127.83393 ],
#        [128.49504 ],
#        [128.47647 ],
#        [129.29564 ],
#        [130.54674 ],
#        [129.03706 ],
#        [130.13396 ],
#        [137.56577 ],
#        [142.02896 ],
#        [142.74695 ],
#        [141.33945 ],
#        [145.75621 ],
#        [143.45212 ],
#        [143.43587 ],
#        [141.47989 ],
#        [140.80193 ],
#        [138.4834  ],
#        [139.88289 ],
#        [140.09196 ],
#        [141.55402 ],
#        [141.60062 ],
#        [139.98457 ],
#        [139.19885 ],
#        [138.88005 ],
#        [138.08195 ],
#        [143.5124  ],
#        [141.23944 ],
#        [143.22224 ],
#        [143.1509  ],
#        [142.57729 ],
#        [141.20656 ],
#        [140.60616 ],
#        [137.02083 ],
#        [139.32301 ],
#        [140.8986  ],
#        [144.66771 ],
#        [144.78947 ],
#        [146.25629 ],
#        [145.63979 ],
#        [142.76747 ],
#        [151.22647 ],
#        [150.91086 ],
#        [148.05458 ],
#        [149.99516 ],
#        [150.1036  ],
#        [149.61713 ],
#        [150.02783 ],
#        [151.40886 ],
#        [152.15465 ],
#        [152.50986 ],
#        [150.01476 ],
#        [150.3901  ],
#        [152.92934 ],
#        [151.27339 ],
#        [149.95927 ],
#        [148.97159 ],
#        [147.746   ],
#        [149.8304  ],
#        [151.84515 ],
#        [150.94058 ],
#        [151.49301 ],
#        [151.24289 ],
#        [153.26302 ],
#        [151.59329 ],
#        [152.52805 ],
#        [157.17455 ],
#        [155.56924 ],
#        [154.54793 ],
#        [151.5239  ],
#        [151.92256 ],
#        [153.4879  ],
#        [154.29767 ],
#        [153.3949  ],
#        [152.02197 ],
#        [154.01305 ],
#        [153.90701 ],
#        [152.24535 ],
#        [146.9382  ],
#        [148.99945 ],
#        [147.54027 ],
#        [144.51488 ],
#        [141.56206 ],
#        [142.91672 ],
#        [146.84511 ],
#        [145.49283 ],
#        [145.43149 ],
#        [149.19888 ],
#        [152.21274 ],
#        [154.49931 ],
#        [154.38156 ],
#        [152.24936 ],
#        [154.83125 ],
#        [153.87651 ],
#        [153.62135 ],
#        [151.34233 ],
#        [155.78354 ],
#        [157.84279 ],
#        [158.31645 ],
#        [157.28947 ],
#        [155.46576 ],
#        [156.01047 ],
#        [156.02669 ],
#        [153.97108 ],
#        [150.4307  ],
#        [146.80748 ],
#        [148.72783 ],
#        [148.29396 ],
#        [150.38492 ],
#        [151.3749  ],
#        [149.75578 ],
#        [155.72522 ],
#        [152.95969 ],
#        [157.13223 ],
#        [166.0172  ],
#        [168.60771 ],
#        [172.38713 ],
#        [173.62234 ],
#        [172.0376  ],
#        [174.99243 ],
#        [171.35828 ],
#        [172.98598 ],
#        [168.9917  ],
#        [170.16115 ],
#        [168.00606 ],
#        [169.2891  ],
#        [170.40944 ],
#        [166.48216 ],
#        [167.42397 ],
#        [167.97455 ],
#        [165.87048 ],
#        [163.53882 ],
#        [165.27592 ],
#        [165.13771 ],
#        [169.08914 ],
#        [164.48038 ],
#        [160.55821 ],
#        [154.79778 ],
#        [163.19017 ],
#        [177.92299 ],
#        [192.52759 ],
#        [187.26984 ],
#        [190.79526 ],
#        [192.33446 ],
#        [185.21933 ],
#        [192.95497 ],
#        [189.70706 ],
#        [188.63863 ],
#        [185.81677 ],
#        [192.98843 ],
#        [193.29001 ],
#        [192.46849 ],
#        [188.18344 ],
#        [192.1733  ],
#        [201.2638  ],
#        [199.84518 ],
#        [200.66013 ],
#        [203.00832 ],
#        [205.39935 ],
#        [200.01038 ],
#        [205.36203 ],
#        [203.27486 ],
#        [205.91956 ],
#        [208.52081 ],
#        [205.43149 ],
#        [204.18704 ],
#        [193.31627 ],
#        [190.26424 ],
#        [198.99113 ],
#        [192.29736 ],
#        [197.05516 ],
#        [199.77399 ],
#        [199.95049 ],
#        [198.36298 ],
#        [203.05994 ],
#        [202.75801 ],
#        [201.1807  ],
#        [201.52362 ],
#        [202.45663 ],
#        [204.854   ],
#        [202.70609 ],
#        [202.17465 ],
#        [203.03862 ],
#        [199.4039  ],
#        [197.58852 ],
#        [196.4933  ],
#        [203.20525 ],
#        [198.24416 ],
#        [202.95338 ],
#        [213.34206 ],
#        [218.05112 ],
#        [216.90791 ],
#        [217.64235 ],
#        [215.99623 ],
#        [214.93507 ],
#        [224.18568 ],
#        [212.91399 ],
#        [213.71939 ],
#        [229.53807 ],
#        [222.75943 ],
#        [221.20523 ],
#        [233.71655 ],
#        [235.49956 ],
#        [235.28642 ],
#        [242.62184 ],
#        [254.64854 ],
#        [249.9828  ],
#        [250.8428  ],
#        [251.14598 ],
#        [253.85712 ],
#        [251.59102 ],
#        [260.52234 ],
#        [251.82692 ],
#        [258.9443  ],
#        [254.54495 ],
#        [250.81657 ],
#        [252.41302 ],
#        [247.64275 ],
#        [256.16226 ],
#        [258.6385  ],
#        [266.00244 ],
#        [255.79176 ],
#        [254.51576 ],
#        [254.88487 ],
#        [256.63464 ],
#        [259.5371  ],
#        [266.99396 ],
#        [265.70425 ],
#        [264.9785  ],
#        [267.1804  ],
#        [269.0373  ],
#        [267.96188 ],
#        [268.71622 ],
#        [276.09952 ],
#        [271.66183 ],
#        [270.65747 ],
#        [270.89536 ],
#        [271.3721  ],
#        [271.61652 ],
#        [275.04404 ],
#        [272.52838 ],
#        [271.86063 ],
#        [271.38385 ],
#        [280.81418 ],
#        [276.9904  ],
#        [272.19943 ],
#        [271.04825 ],
#        [264.7867  ],
#        [268.1518  ],
#        [268.1829  ],
#        [266.84854 ],
#        [265.01358 ],
#        [265.56268 ],
#        [263.718   ],
#        [265.88916 ],
#        [254.91539 ],
#        [255.0177  ],
#        [244.22331 ],
#        [244.6392  ],
#        [239.89647 ],
#        [252.29677 ],
#        [251.72879 ],
#        [249.68309 ],
#        [256.344   ],
#        [252.88625 ],
#        [250.6603  ],
#        [248.3009  ],
#        [242.00598 ],
#        [238.66495 ],
#        [242.87257 ],
#        [238.54735 ],
#        [246.7626  ],
#        [248.52768 ],
#        [249.28735 ],
#        [249.74068 ],
#        [249.07922 ],
#        [249.79536 ],
#        [248.26256 ],
#        [243.74173 ],
#        [248.54524 ],
#        [243.3754  ],
#        [250.78229 ],
#        [251.7358  ],
#        [251.44347 ],
#        [252.50859 ],
#        [245.95096 ],
#        [236.43924 ],
#        [239.75455 ],
#        [240.50911 ],
#        [236.36783 ],
#        [236.45166 ],
#        [240.77196 ],
#        [241.7236  ],
#        [237.00053 ],
#        [253.95567 ],
#        [249.76413 ],
#        [245.4126  ],
#        [248.99658 ],
#        [247.97269 ],
#        [252.19345 ],
#        [249.32967 ],
#        [248.07494 ],
#        [248.36903 ],
#        [249.6545  ],
#        [252.91931 ],
#        [253.35854 ],
#        [255.81204 ],
#        [257.0916  ],
#        [256.6931  ],
#        [254.2538  ],
#        [254.18245 ],
#        [259.1595  ],
#        [259.83633 ],
#        [260.1554  ],
#        [264.55573 ],
#        [259.55698 ],
#        [255.0091  ],
#        [256.95065 ],
#        [261.84924 ],
#        [257.02252 ],
#        [259.68307 ],
#        [253.78229 ],
#        [256.58365 ],
#        [228.44743 ],
#        [221.69057 ],
#        [222.55682 ],
#        [228.50227 ],
#        [225.97897 ],
#        [225.62206 ],
#        [229.81985 ],
#        [232.58978 ],
#        [236.2215  ],
#        [238.85559 ],
#        [240.89917 ],
#        [237.54163 ],
#        [244.27522 ],
#        [247.33286 ],
#        [240.79138 ],
#        [234.3967  ],
#        [243.51805 ],
#        [243.71655 ],
#        [244.29167 ],
#        [244.15483 ],
#        [241.18002 ],
#        [245.17348 ],
#        [246.28241 ],
#        [253.0084  ],
#        [246.74748 ],
#        [250.36447 ],
#        [242.47418 ],
#        [237.9625  ],
#        [236.66852 ],
#        [240.46776 ],
#        [242.10907 ],
#        [244.36984 ],
#        [242.593   ],
#        [241.43079 ],
#        [246.58249 ],
#        [241.33781 ],
#        [256.46152 ],
#        [250.9736  ],
#        [245.65761 ],
#        [242.5682  ],
#        [250.99532 ],
#        [248.95757 ],
#        [244.44385 ],
#        [241.38242 ],
#        [236.40004 ],
#        [222.9225  ],
#        [229.80592 ],
#        [221.04967 ],
#        [216.92854 ],
#        [223.53093 ],
#        [227.68452 ],
#        [229.9358  ],
#        [221.01036 ],
#        [224.49086 ],
#        [227.55623 ],
#        [226.84068 ],
#        [231.2497  ],
#        [220.01955 ],
#        [221.40245 ],
#        [221.00569 ],
#        [225.46585 ],
#        [223.13565 ],
#        [222.13551 ],
#        [223.45345 ],
#        [219.74994 ],
#        [221.22162 ],
#        [224.10995 ],
#        [225.32892 ],
#        [228.50557 ],
#        [230.0358  ],
#        [225.21573 ],
#        [221.01277 ],
#        [217.58182 ],
#        [223.97627 ],
#        [219.6282  ],
#        [221.1057  ],
#        [222.67693 ],
#        [220.78516 ],
#        [223.35353 ],
#        [210.53862 ],
#        [211.12973 ],
#        [210.41669 ],
#        [212.26305 ],
#        [211.3178  ],
#        [205.66304 ],
#        [213.0285  ],
#        [223.44232 ],
#        [224.3572  ],
#        [222.17215 ],
#        [222.38795 ],
#        [222.04543 ],
#        [220.6009  ],
#        [223.38492 ],
#        [221.07922 ]], dtype=float32)

# %% [markdown]
# # Calculating performance

# %%
import math
from sklearn.metrics import mean_squared_error

# %%
performance = math.sqrt(mean_squared_error(ytest,test_predict))
performance
# Out:
# 0.07213446565584625
